# %%
import asyncio
import websockets
import json
import nest_asyncio

nest_asyncio.apply()

async def receive_data(websocket):
    async for message in websocket:
        instrument_data = json.loads(message)
        print(instrument_data)

async def main():
    # Updated to listen on port 8080
    async with websockets.serve(receive_data, "localhost", 8080):
        await asyncio.Future()

await main()
# Out:
# {'cold_output_switch_1': {'state': 'short'}}
# {'cold_output_switch_1': {'state': 'short'}, 'cold_thru_switch_pair': {'state': 'port1'}}
# {'cold_output_switch_1': {'state': 'short'}, 'cold_thru_switch_pair': {'state': 'port1'}, 'cold_output_switch_2': {'state': 'short'}}
# {'cold_output_switch_1': {'state': 'open'}, 'cold_thru_switch_pair': {'state': 'port1'}, 'cold_output_switch_2': {'state': 'short'}}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 18
#      15     async with websockets.serve(receive_data, "localhost", 8080):
#      16         await asyncio.Future()
# ---> 18 await main()
#
# Cell In[3], line 16, in main()
#      13 async def main():
#      14     # Updated to listen on port 8080
#      15     async with websockets.serve(receive_data, "localhost", 8080):
# ---> 16         await asyncio.Future()
#
# ...
